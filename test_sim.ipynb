# %%
from imports import *
import sources as srcs
import propagator as propa
import screens as scrs
import dynamic as dyn

# %%
prop = propa.Propagator()

# %%
out = prop.ism_prop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e992e81ccadd> in <module>
# ----> 1 out = prop.ism_prop()
#
# ~/Documents/research/branched_flow/branchflowsim/propagator.py in ism_prop(self)
#     346         # Simulating propagation
#     347         s = self.get_source()
# --> 348         self.Output = self.splitstep(s, phz)#np.exp(1j * phz))
#     349
#     350         return self.Output
#
# ~/Documents/research/branched_flow/branchflowsim/propagator.py in splitstep(self, Uin, PhaseScreenStack)
#     293         P0 = np.exp(1j * (self.k / (2 * self.dzProps[0])) * (self.r1 ** 2) * (1 - SamplingRatio[0]))
#     294
# --> 295         Uin = P0 * self.Source * np.exp(1j * PhaseScreenStack[:, :, 0])
#     296
#     297         for pcount in range(1, len(self.PropLocs) - 2):
#
# TypeError: unsupported operand type(s) for *: 'complex' and 'NoneType'

# %%
src = srcs.Source()

# %%
p_source = src.PlaneSource()

# %%
scr = scrs.Screen(nx = 1024, ny = 1024, dx = 1, dy = 1, nf = 32)

# %%
ft = scr.ft_phase_screen()

# %%
plt.imshow(ft)

# %%
kol, weights = scr.kolmogorov()

# %%
plt.imshow(kol)

# %%
p_src = prop.get_source()

# %%
plt.imshow(p_src.real)

# %%
amp, efield = prop.plane_free_space()

# %%
plt.imshow(amp)

# %%
plt.imshow(efield.real)

# %%
import wavepy2 as wp

# %%
wv = wp.wavepy()

# %%
nscr = 5
phs_stk = np.zeros((256, 256, nscr+1))
for n in range(nscr+1):
    phs = wv.PhaseScreen(16)
    phs_stk[:, :, n] = phs

# %%
import infinitescreen as infscr

# %%
phscr = infscr.PhaseScreen()
kol = infscr.PhaseScreenKolmogorov(phscr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-eb62c9e28bf2> in <module>
#       1 phscr = infscr.PhaseScreen()
# ----> 2 kol = infscr.PhaseScreenKolmogorov(phscr)
#
# ~/Documents/research/branched_flow/branchflowsim/infinitescreen.py in __init__(self, req_nx_size, pixel_scale, r0, L0, random_seed, stencil_length_factor)
#     247         n = np.asarray([0])
#     248         nx_size = np.asarray([0])
# --> 249         while (2 ** n + 1) <= int(self.req_nx_size):
#     250             n += 1
#     251             nx_size = 2 ** n + 1
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'PhaseScreen'
